# %% [markdown]
# ## Pypolt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])
# plt.plot([4,3,2,1])
# plt.xlabel("more numeros")
# plt.ylabel("numeros")
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'bo')
plt.show()

# %%
t = np.arange(0., 5., 0.2)
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# $$ y = 2x$$

# %%
x = np.linspace(0.0,100.0,11) # creates an array of evenly space numbers
y1 = 2*x + 5
y2 = 1 * x  - 5
y3 = -2* x + 0

plt.plot(x,y1,'r')
plt.plot(x,y2,'b')
plt.plot(x,y3,'g')

plt.show()

# %%
y1
# Out:
# array([    0.,   100.,   400.,   900.,  1600.,  2500.,  3600.,  4900.,
#         6400.,  8100., 10000.])
